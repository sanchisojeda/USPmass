# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as op
import emcee
import transit
import george
from george import kernels

# %% [markdown]
# I first read the data obtained with the Keck telescope into the frame data

# %%
newdata = pd.read_table('Keckdata.txt', skiprows=[0, 2], sep='\s+')

# %% [markdown]
# And I select the three important variables, with the option to add an error in quadrature

# %%
bjd = np.array(newdata['JD-2.44e6'], 'd')
rvs = np.array(newdata['mnvel'], 'd')
rverr = np.array(newdata['errvel'], 'd')
additionalerr = 0.0

# %% [markdown]
# Now I use the orbital ephemeris obtained from the transits to define the orbital phases, and I also define a new zero point for the BJD timestamps

# %%
period = 0.6892099
tc = 2454953.1910
tc = tc-2440000.0

phasesaux = (bjd-tc)/period
phases, orbit = np.modf(phasesaux)

phases = phases
bjdlv = np.mean(bjd)
bjdrest, bjdint = np.modf(bjdlv)

phi0 = (bjdint-tc)/period
aux, phi0 = phi0-np.modf(phi0)

shortbjd = bjd-bjdint

# %% [markdown]
# Now I define a function that calculates the log of the likelihood for the fit

# %%
def simplemodel(theta, phases):
    K, a, gamma, prot, h  = theta
    return -K*np.sin(2.0*np.pi*phases) + a

# %%
def lnlike(theta, phases, shortbjd, rvs, error):
    "Model to fit a sinusoid to the RV data"
    K, a, gamma, prot, h = theta

    theoRV = simplemodel(theta, phases)
    
    gp = george.GP(kernels.ExpSine2Kernel(gamma, prot)*h**2)
    gp.compute(shortbjd, error)
    return gp.lnlikelihood(rvs - simplemodel(theta, phases))

# %%
def lnprior(theta):
    K, a, gamma, prot, h= theta
    if  0 <= gamma and 0 <= h:
        return -0.5*((prot-30.0)/1.0)**2
    return -np.inf

# %%
def lnprob(theta, phases, shortbjd, rvs, error):
    lp = lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + lnlike(theta, phases, shortbjd, rvs, error)

# %% [markdown]
# And I obtain the best fit parameters, their uncertainties, and I plot the observations and the model

# %%
nll = lambda *args: -lnprob(*args)
result = op.minimize(nll, [4.0, 0.0, 1.0, 30, 5.0], 
                     args=(phases, shortbjd, rvs, rverr), tol=0.01, options={'disp': True, 'maxiter':100000}, method='BFGS')
K_ml, a_ml, gamma_ml, prot_ml, h_ml = result["x"]
error = np.sqrt(rverr**2+ 0.0*sigma_ml**2)
print result["x"]
# Out:
# Optimization terminated successfully.
#          Current function value: 69.233523
#          Iterations: 24
#          Function evaluations: 249
#          Gradient evaluations: 31
# [  3.63137217  -3.20819535   2.39551337  10.25163664  30.76394614
#    5.96551214]

# %% [markdown]
# With the best fit solution, it is time to run and MCMC routine to estimate the uncertainties on the parameters

# %%
ndim, nwalkers = 5, 100
pos = [result["x"]*(1+5e-3*np.random.randn(ndim)) for i in range(nwalkers)]

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(phases, shortbjd, rvs, rverr))
sampler.run_mcmc(pos, 1000)
# Out:
# (array([[  5.15446095e-01,   1.62327790e-01,   4.55957701e+00,
#            2.09118009e+32,   3.05991199e+01,   7.53469961e+00],
#         [  6.95908965e+00,   1.34391889e+00,   1.32764590e+00,
#            3.94041686e+32,   2.83936153e+01,   7.81147535e+00],
#         [  4.60790213e+00,  -4.13871520e-01,   5.61732887e+00,
#          1111612878, 1110363124,   33444697, 2795634129, 3606453902,
#           223285535, 1504768482,  221898217, 1465267742, 1137242293,
#          1973675718, 2240586642, 3363784583, 3686010831, 2897323429,
#          1567312509, 3155322820, 1926048794, 2710054182, 4277393455,
#          3203576293, 3644654188,  399425467, 3896867118,  572226458,
#          1370974213, 2438969850, 2964466665, 2027767820, 2051825763,
#          3868339012, 4043360665, 1180836637, 1509779351, 1984492735,
#           150814784, 1910430599, 1914208715, 2244601184, 3680702639,
#          1452008826, 2622494946, 2742214736, 3643049608,  549384663,
#          4271546547, 2465683849, 1735923854,  933013519, 3032925967,
#          3143051969,   66243484, 2352378001, 2662316715,  276103603,
#          1580040095, 3365073097, 4136695082, 2105180037, 4011571067,
#          3346880320, 3474651199, 3691609982, 1860710268, 2671940195,
#          2753034522, 2425315550, 3181366450, 1472513119, 3161907734,
#          1250830387,  508549334, 1098656110, 3581328621, 1940172136,
#          1849588635, 3993138088, 1298135358, 3448062770, 2343583643,
#          2456233851, 3830149043, 2362402898, 3575877273, 1085557081,
#          3427904078, 1899864385, 2189723673, 3718353128], dtype=uint32), 274, 0, 0.0))

# %%
samples = sampler.chain[:, 100:, :].reshape((-1, ndim)) #Burn in portion to remove (currently %10)

# %% [markdown]
# Now I plot the results in a triangle plot

# %%
import triangle
fig = triangle.corner(samples, labels=["K", "a", "gamma", "Prot", "h"]) #truths=[m_true, b_true, np.log(f_true)   , 
fig.savefig("triangle.png")

# %%
(K_mcmc, a_mcmc,sigma_mcmc, gamma_mcmc, prot_mcmc, h_mcmc) = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]), 
                                  zip(*np.percentile(samples, [15.86, 50, 84.14], axis=0)))

# %%
print('K value {0:3.2f} +{1:3.2f} - {1:3.2f}' .format(K_mcmc[0],K_mcmc[1], K_mcmc[2] ))
# Out:
# K value 3.49 +1.49 - 1.49

# %%
fig = plt.figure(figsize=(14,4))
ax = fig.add_subplot(1,2,1)
ax.scatter(shortbjd, rvs)
ax.errorbar(shortbjd, rvs, yerr=error, fmt='o')
plt.xlim([-50, 50]) 
plt.ylim([-19, 19]) 

ax.set_xlabel('Time [BJD]')
ax.set_ylabel('Radial velocity [m/s]')

theoRV = -K_ml*np.sin(2.0*np.pi*phases) + a_ml 

newbjd = np.linspace(-50, 50, 500)
newx = (newbjd/period) + phi0
newphases, orbit = np.modf(newx)



# Plot 24 posterior samples.
samples = sampler.flatchain
for s in samples[np.random.randint(len(samples), size=24)]:
    # Set up the GP for this sample.
    K, a, sigma, gamma, prot, h = s
    gp = george.GP(kernels.WhiteKernel(np.sqrt(sigma))+kernels.ExpSine2Kernel(gamma, prot)*h**2)
    gp.compute(shortbjd, error)
        
    # Compute the prediction conditioned on the observations and plot it.
    m = gp.sample_conditional(rvs - simplemodel(s, phases), newbjd ) + simplemodel(s, newbjd)
    ax.plot(newbjd, m, color="#4682b4", alpha=0.3)
    
    
ax.errorbar(shortbjd, rvs, yerr=error, fmt='o')
# Out:
# <Container object of 3 artists>
